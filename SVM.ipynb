# %% [markdown]
# ### SVM na prática

# %%
import pandas as pd

# %%
cancer = pd.read_csv("data\cancer_data.csv", sep=";")
cancer.head()
# Out:
#          id diagnosis radius_mean texture_mean perimeter_mean area_mean  \
# 0    842302         M       17,99        10,38          122,8      1001
# 1    842517         M       20,57        17,77          132,9      1326
# 2  84300903         M       19,69        21,25            130      1203
# 3  84348301         M       11,42        20,38          77,58     386,1
# 4  84358402         M       20,29        14,34          135,1      1297
#
#   smoothness_mean compactness_mean concavity_mean concave points_mean  ...  \
# 0          0,1184           0,2776         0,3001              0,1471  ...
# 1         0,08474          0,07864         0,0869             0,07017  ...
# 2          0,1096           0,1599         0,1974              0,1279  ...
# 3          0,1425           0,2839         0,2414              0,1052  ...
# 4          0,1003           0,1328          0,198              0,1043  ...
#
#   radius_worst texture_worst perimeter_worst area_worst smoothness_worst  \
# ...

# %% [markdown]
# Separar coluna de predição do diagnóstico

# %%
cancer.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
x_columns = ['radius_mean', 'texture_mean', 'perimeter_mean',
       'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
       'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
       'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
       'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
       'fractal_dimension_se', 'radius_worst', 'texture_worst',
       'perimeter_worst', 'area_worst', 'smoothness_worst',
       'compactness_worst', 'concavity_worst', 'concave points_worst',
       'symmetry_worst', 'fractal_dimension_worst']
y_columns = ['diagnosis']

# %%
X = cancer[x_columns]
y = cancer[y_columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train.head()
# Out:
#     radius_mean texture_mean perimeter_mean area_mean smoothness_mean  \
# 178       13,01        22,22          82,01     526,4         0,06251
# 421       14,69        13,98          98,22     656,1          0,1031
# 57        14,71        21,59          95,55     656,9          0,1137
# 514       15,05        19,07          97,26     701,9         0,09215
# 548       9,683        19,34          61,05     285,7         0,08491
#
#     compactness_mean concavity_mean concave points_mean symmetry_mean  \
# 178          0,01938       0,001595            0,001852        0,1395
# 421           0,1836          0,145               0,063        0,2086
# 57            0,1365         0,1293             0,08123        0,2027
# 514          0,08597        0,07486             0,04335        0,1561
# 548           0,0503        0,02337            0,009615         0,158
#
#     fractal_dimension_mean  ... radius_worst texture_worst perimeter_worst  \
# ...

# %%
for column in X_train.columns:
     X_train[column] = X_train[column].str.replace(',', '.').astype(float)

# %%
from sklearn.svm import SVC

# %%
model = SVC() # SVC: Support Vector Composed

# %%
model.fit(X_train, y_train)
# Out:
# C:\Users\maria\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1310: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC()

# %%
preds = model.predict(X_test)
preds
# Out:
# array(['B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'B',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'B', 'M',
#        'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'B',
#        'B', 'M', 'B', 'B', 'M', 'M', 'B', 'B', 'M', 'B', 'B', 'B', 'M',
#        'B', 'B', 'M', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B',
#        'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B',
#        'M', 'M', 'M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'M', 'M', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M', 'B', 'M',
#        'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'M',
#        'B', 'M', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B', 'B', 'B',
#        'B', 'B'], dtype=object)

# %% [markdown]
# Comparando com y_test

# %%
from sklearn.metrics import accuracy_score

# %%
porcentagem = accuracy_score(y_test, preds) * 100
print("Porcentage de acerto do modelo: ", str(porcentagem) + "%")
# Out:
# Porcentage de acerto do modelo:  92.39766081871345%
